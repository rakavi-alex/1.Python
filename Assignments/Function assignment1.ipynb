# %%
def Subfields():
  
  print("Sub-Fields in AI are :")
  for temp in lists:
        print(temp)

# %%
lists=['Machine Learning' , 'Neural Networks' , 'Vision' , 'Robotics', 'Speech Processing' , 'Natural Langugae Processing']
output=Subfields()
# Out:
# Sub-Fields in AI are :
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Langugae Processing

# %%
def OddEven():
    num=int(input("Enter the Number"))
    if((num%2)==1):
        print(num,"is Odd number")
        message=" is Odd number"
    else: 
        print(num," is Even number")
        message="is Even number"

# %%
OddEven()
# Out:
# Enter the Number 44
# 44  is Even number

# %%
def eligible():
        age=int(input("Enter your Age"))
        if (age>18):
          print(" Is Eligible For Marriage")
        else:
          print(" Is Not Eligible for Marriage")

# %%
age=eligible()
# Out:
# Enter your Age 32
#  Is Eligible For Marriage

# %%
def percentage():
   subject1=int(input("Subject1"))
   subject2=int(input("Subject2"))
   subject3=int(input("Subject3"))
   subject4=int(input("Subject4"))
   subject5=int(input("Subject5"))
   total=subject1+subject2+subject3+subject4+subject5
   percentage=(total/500)*100
   print(total,"Total")
   print(percentage,"Percentage")

# %%
percentage()
# Out:
# Subject1 92
# Subject2 93
# Subject3 89
# Subject4 91
# Subject5 99
# 464 Total
# 92.80000000000001 Percentage

# %%
def triangle():
    # 1. Calculate Area
    height=float(input("Height :"))
    breadth=float(input("Breadth :"))
    print("Area formula:  (Height*Breadth)/2")
    Area=(height*breadth)/2
    print("Area of Triangle",Area)
   
    # 2. Calculate Perimeter
    Height1=float(input("Height1 :"))
    Height2=float(input("Height2 :"))
    Breadth=float(input("Breadth :"))
    print("Perimeter formula: Height1+Height2+Breadth")
    Perimeter=Height1+Height2+Breadth
    print("Permeter of Triangle",Perimeter)
triangle()
# Out:
# Height : 6
# Breadth : 4
# Area formula:  (Height*Breadth)/2
# Area of Triangle 12.0
# Height1 : 4
# Height2 : 4
# Breadth : 3
# Perimeter formula: Height1+Height2+Breadth
# Permeter of Triangle 11.0
