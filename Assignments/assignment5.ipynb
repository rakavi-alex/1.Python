# %%
i = 10
if i == 10:
    print("correct")
# Out:
# correct

# %%
password = input(" Enter the Password: ")
if password == "12345":
        print("Your Password is Correct.")
else:
        print("Incorrect password.")
# Out:
#  Enter the Password:  12345
# Your Password is Correct.

# %%
age=int(input("Enter the Age"))
# Out:
# Enter the Age 40

# %%
if(age<18):
      print("children")
elif(age<30):
      print("adult")
elif(age<55):
      print("citizen")
else:
      print("senior citizen")
# Out:
# citizen

# %%
num = float(input("Enter any number: "))

if num > 0:
    print(" Number is Positive")
elif num == 0:
    print("Zero")
else:
    print("Number is Negative")
# Out:
# Enter any number:  -2
# Number is Negative

# %%
num= int(input("ENter the Number"))
if num % 5 == 0:
    print(num,"Divisible by 0")
else:
    print(num,"Not Divisible by 0")
# Out:
# ENter the Number 90
# 90 Divisible by 0

# %%
num= int(input("ENter the Number"))
if num % 5 == 0:
    print(num,"Divisible by 0")
else:
    print(num,"Not Divisible by 0")
# Out:
# ENter the Number 56
# 56 Not Divisible by 0
