# %%
print("Welcome to assignment 1")
# Out:
# Welcome to assignment 1

# %%
num1=45
num2=20
add=num1+num2
print("Num1=",num1)
print("Num2=",num2)
print("Add=",add)
# Out:
# Num1= 45
# Num2= 20
# Add= 65
