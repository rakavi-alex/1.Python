# %%
 print("Welcome to HOPE AI Assignment")
# Out:
# Welcome to HOPE AI Assignment

# %%
name=input("Enter your Institute name:")
# Out:
# Enter your Institute name: hope ai

# %%
name=input("Enter your Name:")
age=input("Enter your Age:")
name=input("Enter your School Name:")
name=input("Enter your Degree:")
# Out:
# Enter your Name: Rakavi R
# Enter your Age: 30
# Enter your School Name: KGHSS
# Enter your Degree: MCA

# %%
a=40
b=20
add=a+b
print("ADD =",add)
# Out:
# ADD = 60

# %%
a=40
b=20
sub=a-b
print("Subtraction :",sub)
mul=a*b
print("Multiplication :",mul)
div=a/b
print("Division :",div)
div=a//b
print("Floor division :",div)
div=a%b
print("Modulo Division :",div)
pow=(a,b)
print("Power :",pow)
# Out:
# Subtraction : 20
# Multiplication : 800
# Division : 2.0
# Floor division : 2
# Modulo Division : 0
# Power : (40, 20)
