# %%
num1=20
num2=50
add=num1+num2
print("answer")
print(add)
# Out:
# answer
# 70

# %%
Num1=10
Num2=40
Add=Num1+Num2
Sub=Num1-Num2
print("answer")
print(Add)
print(Sub)
# Out:
# answer
# 50
# -30

# %%
FirstName=Rakavi
print(FirstName)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 FirstName=Rakavi
#       2 print(FirstName)
#
# NameError: name 'Rakavi' is not defined

# %%
num1=10
num2=30
add=num1+num2
print("The Addition of two numbers")
print("The number:",num1)
print("The number:",num2)
print("The Answer",add)
# Out:
# The Addition of two numbers
# The number: 10
# The number: 30
# The Answer 40
